# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas
x = np.linspace(-5, 5, 20)

# %%
# from google.colab import files
# uploaded = files.upload()
# Out:
#      <input type="file" id="files-7088e578-6559-4e4c-85bc-91185f3a54d9" name="files[]" multiple disabled />
#      <output id="result-7088e578-6559-4e4c-85bc-91185f3a54d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving brain_size.csv to brain_size.csv

# %%
np.random.seed(1)
y = -5 + 3 * x + 4 * np.random.normal(size = x.shape)

# %%
data = pandas.DataFrame({'x' : x, 'y' : y})

# %%
from statsmodels.formula.api import ols
model = ols("y ~ x", data).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     74.03
# Date:                Wed, 30 Oct 2019   Prob (F-statistic):           8.56e-08
# Time:                        07:14:14   Log-Likelihood:                -57.988
# No. Observations:                  20   AIC:                             120.0
# Df Residuals:                      18   BIC:                             122.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.5335      1.036     -5.342      0.000      -7.710      -3.357
# ...

# %%
data = pandas.read_csv('brain_size.csv', sep = ';', na_values=".")

# %%
y_reg =  2.9369 * x + -5.5335 + 1.036 + 0.341
plt.plot(x, y, 'bo', x, y_reg)

# %%
model = ols("VIQ ~ Gender + 1", data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    VIQ   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5969
# Date:                Tue, 29 Oct 2019   Prob (F-statistic):              0.445
# Time:                        15:02:18   Log-Likelihood:                -182.42
# No. Observations:                  40   AIC:                             368.8
# Df Residuals:                      38   BIC:                             372.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        109.4500      5.308     20.619      0.000      98.704     120.196
# ...

# %%
uploaded_2 = files.upload()
# Out:
#      <input type="file" id="files-f3c32e6d-da52-4591-95da-9887720e2c77" name="files[]" multiple disabled />
#      <output id="result-f3c32e6d-da52-4591-95da-9887720e2c77">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris.csv to iris.csv

# %%
data_2 = pandas.read_csv('iris.csv')

# %%
model = ols('sepal_width ~ name + petal_length', data_2).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            sepal_width   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     44.63
# Date:                Tue, 29 Oct 2019   Prob (F-statistic):           1.58e-20
# Time:                        15:21:15   Log-Likelihood:                -38.185
# No. Observations:                 150   AIC:                             84.37
# Df Residuals:                     146   BIC:                             96.41
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.9813      0.099     29.989      0.000       2.785       3.178
# ...

# %%
print(model.f_test([0, 1, -1, 0]))
# Out:
# <F test: F=array([[3.24533535]]), p=0.07369058781701113, df_denom=146, df_num=1>

# %% [markdown]
# Regresi Linier menggunakan TensorFlow

# %%
# import tensorflow as tf
# from tensorflow import keras
# model = tf.keras.Sequential([keras.layers.Dense(units=64),
#                              keras.layers.Dense(1)])
# model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# model.fit(x, y, epochs=500)
# Out:
# Train on 20 samples
# Epoch 1/500
# 20/20 [==============================] - 0s 5ms/sample - loss: 142.2926
# Epoch 2/500
# 20/20 [==============================] - 0s 94us/sample - loss: 55.9896
# Epoch 3/500
# 20/20 [==============================] - 0s 155us/sample - loss: 42.3625
# Epoch 4/500
# 20/20 [==============================] - 0s 84us/sample - loss: 38.4023
# Epoch 5/500
# 20/20 [==============================] - 0s 141us/sample - loss: 35.0451
# Epoch 6/500
# 20/20 [==============================] - 0s 92us/sample - loss: 32.1489
# Epoch 7/500
# 20/20 [==============================] - 0s 106us/sample - loss: 29.6615
# Epoch 8/500
# 20/20 [==============================] - 0s 119us/sample - loss: 27.5445
# Epoch 9/500
# 20/20 [==============================] - 0s 130us/sample - loss: 25.7655
# Epoch 10/500
# 20/20 [==============================] - 0s 129us/sample - loss: 24.2938
# Epoch 11/500
# 20/20 [==============================] - 0s 102us/sample - loss: 23.0978
# ...

# %%
# y_reg_tf = model.predict(x)

# %%
# plt.plot(x,y,'bo',x, y_reg_tf)
